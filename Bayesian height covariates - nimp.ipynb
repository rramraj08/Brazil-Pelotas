# %%
import pandas as pd
import numpy as np
import arviz as az

# %%
df_brazil = pd.read_excel(r'alldatasets.xlsx',sheet_name='Brazil')

# %%
df_brazil.head()
# Out:
#   childid country  height  stunting_2cat  EDUYRS2   z_score  agegapr1  \
# 0     BR0  Brazil  180.65            0.0     13.0  1.510429       7.0
# 1     BR1  Brazil  180.35            0.0     16.0  0.399053       0.0
# 2     BR2  Brazil  164.95            0.0     15.0  0.002132       NaN
# 3     BR3  Brazil  182.30            0.0      4.0 -1.823701       NaN
# 4     BR4  Brazil     NaN            NaN      NaN       NaN       NaN
#
#    momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  job_cat  pvt_sector  \
# 0          8.0      1.0      47.0       4.0  0.882373      3.0         0.0
# 1          5.0      1.0      50.0       3.0  0.306352      3.0         1.0
# 2          5.0      0.0      52.0       3.0  0.533106      3.0         1.0
# 3          9.0      1.0      49.0       8.0  0.777917      NaN         NaN
# 4         15.0      1.0       NaN       NaN       NaN      NaN         NaN
#
#      earn_usd
# 0  707.225360
# 1  290.316010
# 2  109.973544
# 3    0.000000
# 4         NaN

# %%
df_brazil.columns
# Out:
# Index(['childid', 'country', 'height', 'stunting_2cat', 'EDUYRS2', 'z_score',
#        'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1', 'hhsizer1',
#        'wi_newr1', 'job_cat', 'pvt_sector', 'earn_usd'],
#       dtype='object')

# %%
from scipy import stats
import scipy.stats as stats

# %%
import seaborn as sns
sns.displot(df_brazil, x="height", hue="stunting_2cat", kind="kde", multiple="stack")

# %% [markdown]
# # Bayesian

# %%
Y = df_brazil[['height']]
X = df_brazil[['stunting_2cat']]

# %%
formula = 'height ~ ' + ' + '.join(['%s' % variable for variable in X.columns[0:]])
formula
# Out:
# 'height ~ stunting_2cat'

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pymc3 as pm

# Context for the model
with pm.Model() as normal_model:
    
    my_priors= {
        'Intercept': pm.Normal.dist(mu=168.7, sigma=10.),
        'stunting_2cat': pm.Normal.dist(mu=1, sigma=7.8)        
    }
    
    
    
    # Creating the model requires a formula and data (and optionally a family)
    pm.GLM.from_formula(formula, data = df_brazil, priors=my_priors)
    
    # Perform Markov Chain Monte Carlo sampling letting PyMC3 choose the algorithm
    normal_trace = pm.sample(draws=3000, chains = 2, tune = 4000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [sd, stunting_2cat, Intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14000' class='' max='14000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [14000/14000 00:10<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 4_000 tune and 3_000 draw iterations (8_000 + 6_000 draws total) took 20 seconds.

# %%
az.summary(normal_trace)
# Out:
#                   mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_mean  \
# Intercept      168.693  0.167  168.375  168.991      0.002    0.002    5943.0
# stunting_2cat   -8.786  0.515   -9.707   -7.819      0.007    0.005    6046.0
# sd               8.741  0.112    8.542    8.955      0.001    0.001    6227.0
#
#                ess_sd  ess_bulk  ess_tail  r_hat
# Intercept      5942.0    5939.0    3565.0    1.0
# stunting_2cat  6046.0    6041.0    4531.0    1.0
# sd             6227.0    6234.0    4070.0    1.0

# %%
az.plot_trace(normal_trace)
# Out:
# array([[<AxesSubplot:title={'center':'Intercept'}>,
#         <AxesSubplot:title={'center':'Intercept'}>],
#        [<AxesSubplot:title={'center':'stunting_2cat'}>,
#         <AxesSubplot:title={'center':'stunting_2cat'}>],
#        [<AxesSubplot:title={'center':'sd'}>,
#         <AxesSubplot:title={'center':'sd'}>]], dtype=object)

# %%
Y = df_brazil['height']
X = df_brazil[['stunting_2cat', 'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1','wi_newr1',
       'hhsizer1']]

# %%
formula = 'height ~ ' + ' + '.join(['%s' % variable for variable in X.columns[0:]])
formula
# Out:
# 'height ~ stunting_2cat + agegapr1 + momeduyrsr1 + chsexr1 + agemonr1 + wi_newr1 + hhsizer1'

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pymc3 as pm

# Context for the model
with pm.Model() as normal_model:
    
    my_priors= {
        'Intercept': pm.Normal.dist(mu=168.7, sigma=10),
        'stunting_2cat': pm.Normal.dist(mu=1, sigma=7.8),
        'agegapr1': pm.Normal.dist(mu=1, sigma=7.8),
        'momeduyrsr1': pm.Normal.dist(mu=1, sigma=7.8),
        'chsexr1': pm.Normal.dist(mu=1, sigma=7.8),
        'agemonr1': pm.Normal.dist(mu=1, sigma=7.8),
        'wi_newr1': pm.Normal.dist(mu=1, sigma=7.8),
        'hhsizer1': pm.Normal.dist(mu=1, sigma=7.8) 
    }
    
    
    
    # Creating the model requires a formula and data (and optionally a family)
    pm.GLM.from_formula(formula, data = df_brazil, priors=my_priors)
    
    # Perform Markov Chain Monte Carlo sampling letting PyMC3 choose the algorithm
    normal_trace = pm.sample(draws=5000, chains = 2, tune = 8000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [sd, hhsizer1, wi_newr1, agemonr1, chsexr1, momeduyrsr1, agegapr1, stunting_2cat, Intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='26000' class='' max='26000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [26000/26000 01:41<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 8_000 tune and 5_000 draw iterations (16_000 + 10_000 draws total) took 111 seconds.

# %%
az.summary(normal_trace)
# Out:
#                   mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_mean  \
# Intercept      161.176  1.482  158.327  163.869      0.021    0.015    5132.0
# stunting_2cat   -8.528  0.424   -9.339   -7.747      0.004    0.003   11189.0
# agegapr1        -0.026  0.031   -0.080    0.034      0.000    0.000   10857.0
# momeduyrsr1      0.142  0.034    0.079    0.210      0.000    0.000    6541.0
# chsexr1         13.048  0.246   12.579   13.511      0.003    0.002    8023.0
# agemonr1        -0.006  0.033   -0.066    0.057      0.000    0.000    5337.0
# wi_newr1         0.830  0.802   -0.690    2.327      0.010    0.007    6179.0
# hhsizer1         0.049  0.072   -0.085    0.184      0.001    0.001    8604.0
# sd               5.849  0.085    5.687    6.006      0.001    0.001    8391.0
#
#                 ess_sd  ess_bulk  ess_tail  r_hat
# Intercept       5124.0    5141.0    5552.0    1.0
# stunting_2cat  11189.0   11215.0    6789.0    1.0
# agegapr1        6819.0   10864.0    7438.0    1.0
# momeduyrsr1     6492.0    6536.0    7340.0    1.0
# chsexr1         8023.0    8051.0    6540.0    1.0
# agemonr1        5042.0    5338.0    5978.0    1.0
# wi_newr1        6018.0    6183.0    6682.0    1.0
# hhsizer1        6697.0    8608.0    7349.0    1.0
# sd              8391.0    8378.0    6890.0    1.0

# %%
az.plot_trace(normal_trace)
# Out:
# array([[<AxesSubplot:title={'center':'Intercept'}>,
#         <AxesSubplot:title={'center':'Intercept'}>],
#        [<AxesSubplot:title={'center':'stunting_2cat'}>,
#         <AxesSubplot:title={'center':'stunting_2cat'}>],
#        [<AxesSubplot:title={'center':'agegapr1'}>,
#         <AxesSubplot:title={'center':'agegapr1'}>],
#        [<AxesSubplot:title={'center':'momeduyrsr1'}>,
#         <AxesSubplot:title={'center':'momeduyrsr1'}>],
#        [<AxesSubplot:title={'center':'chsexr1'}>,
#         <AxesSubplot:title={'center':'chsexr1'}>],
#        [<AxesSubplot:title={'center':'agemonr1'}>,
#         <AxesSubplot:title={'center':'agemonr1'}>],
#        [<AxesSubplot:title={'center':'wi_newr1'}>,
#         <AxesSubplot:title={'center':'wi_newr1'}>],
#        [<AxesSubplot:title={'center':'hhsizer1'}>,
#         <AxesSubplot:title={'center':'hhsizer1'}>],
#        [<AxesSubplot:title={'center':'sd'}>,
#         <AxesSubplot:title={'center':'sd'}>]], dtype=object)

# %%
az.plot_forest(normal_trace);
