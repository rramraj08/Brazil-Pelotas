# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\rramr\OneDrive\Desktop\Modern Scientist Global\dataset\df_knn_for_bayesian.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   age_m_r4  sexr1  Age_gap_r1  maternal_schooling_r1  \
# 0           0  47.408170    1.0    6.991102                    8.0
# 1           1  49.643780    1.0   -0.285421                    5.0
# 2           2  50.465700    0.0    1.331006                    5.0
# 3           3  48.920494    1.0    5.479671                    9.0
# 4           4  42.700227    1.0    8.192471                   15.0
#
#    no_of_household_members_r3  household_assets_index_r3  schooling_y_r5  \
# 0                         4.0                    5.76350            13.0
# 1                         3.0                    2.00260            16.0
# 2                         3.0                    3.48310            15.0
# 3                         8.0                    5.08150             4.0
# 4                         4.2                    4.88618            16.6
#
#    score_waisiii_iq_zscore_r5  Height_adult  ...  Stunting_Yes  Stunting_nan  \
# ...

# %%
from scipy import stats
import scipy.stats as stats

# %%
import statsmodels.api as sm

# %%
X = df["Stunting_Yes"] ## X usually means our input variables (or independent variables)
y = df["score_waisiii_iq_zscore_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     score_waisiii_iq_zscore_r5   R-squared:                       0.038
# Model:                                    OLS   Adj. R-squared:                  0.038
# Method:                         Least Squares   F-statistic:                     233.8
# Date:                        Fri, 12 Mar 2021   Prob (F-statistic):           8.72e-52
# Time:                                12:54:12   Log-Likelihood:                -7604.9
# No. Observations:                        5914   AIC:                         1.521e+04
# Df Residuals:                            5912   BIC:                         1.523e+04
# Df Model:                                   1
# Covariance Type:                    nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X = df["Stunting_Yes"] ## X usually means our input variables (or independent variables)
y = df["schooling_y_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         schooling_y_r5   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     197.6
# Date:                Fri, 12 Mar 2021   Prob (F-statistic):           3.57e-44
# Time:                        12:54:33   Log-Likelihood:                -16175.
# No. Observations:                5914   AIC:                         3.235e+04
# Df Residuals:                    5912   BIC:                         3.237e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["cohort_member_monthly_income_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     cohort_member_monthly_income_r5   R-squared:                       0.010
# Model:                                         OLS   Adj. R-squared:                  0.010
# Method:                              Least Squares   F-statistic:                     33.26
# Date:                             Tue, 09 Mar 2021   Prob (F-statistic):           8.82e-09
# Time:                                     00:30:09   Log-Likelihood:                -30285.
# No. Observations:                             3292   AIC:                         6.057e+04
# Df Residuals:                                 3290   BIC:                         6.059e+04
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["amount_recived_in_reais_last_month_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       OLS Regression Results
# ...
# Dep. Variable:     amount_recived_in_reais_last_month_r5   R-squared:                       0.006
# Model:                                               OLS   Adj. R-squared:                  0.005
# Method:                                    Least Squares   F-statistic:                     14.62
# Date:                                   Tue, 09 Mar 2021   Prob (F-statistic):           0.000135
# Time:                                           00:30:10   Log-Likelihood:                -24589.
# No. Observations:                                   2559   AIC:                         4.918e+04
# Df Residuals:                                       2557   BIC:                         4.919e+04
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ...

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["ISIC labour categories_r5.1"] ## Y usually means our output/dependent variable
X = sm.add_constant(X, prepend = False)## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.Logit(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.513654
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 Logit Regression Results
# ...
# Dep. Variable:     ISIC labour categories_r5.1   No. Observations:                 2693
# Model:                                   Logit   Df Residuals:                     2691
# Method:                                    MLE   Df Model:                            1
# Date:                         Tue, 09 Mar 2021   Pseudo R-squ.:               8.091e-05
# Time:                                 00:30:12   Log-Likelihood:                -1383.3
# converged:                                True   LL-Null:                       -1383.4
# Covariance Type:                     nonrobust   LLR p-value:                    0.6361
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
X = df["Stunting_Yes"] ## X usually means our input variables (or independent variables)
y = df["Height_adult"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Height_adult   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     378.8
# Date:                Fri, 12 Mar 2021   Prob (F-statistic):           7.89e-82
# Time:                        12:55:26   Log-Likelihood:                -20360.
# No. Observations:                5914   AIC:                         4.072e+04
# Df Residuals:                    5912   BIC:                         4.074e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["worked_and_paid_r5.1"] ## Y usually means our output/dependent variable
X = sm.add_constant(X, prepend = False)## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.MNLogit(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.430849
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            MNLogit Regression Results
# ...
# Dep. Variable:     worked_and_paid_r5.1   No. Observations:                 4742
# Model:                          MNLogit   Df Residuals:                     4740
# Method:                             MLE   Df Model:                            1
# Date:                  Tue, 09 Mar 2021   Pseudo R-squ.:                  0.3722
# Time:                          00:30:26   Log-Likelihood:                -2043.1
# converged:                         True   LL-Null:                       -3254.5
# Covariance Type:              nonrobust   LLR p-value:                     0.000
# ...
# worked_and_paid_r5.1=Yes       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
import warnings

warnings.filterwarnings('ignore')

X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["type_of_employment_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X, prepend = False)## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.MNLogit(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# ...
#          Current function value: 0.403361
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             MNLogit Regression Results
# ...
# Dep. Variable:     type_of_employment_r5   No. Observations:                 4742
# Model:                           MNLogit   Df Residuals:                     4736
# Method:                              MLE   Df Model:                            3
# Date:                   Tue, 09 Mar 2021   Pseudo R-squ.:                  0.1359
# Time:                           00:30:28   Log-Likelihood:                -1912.7
# converged:                         False   LL-Null:                       -2213.6
# Covariance Type:               nonrobust   LLR p-value:                4.065e-130
# ...
#                   type_of_employment_r5=Employer       coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
#cats=df['sexr1']

# %%
#cat_dummies = pd.get_dummies(data=cats, drop_first=True,dummy_na=True)

# %%
#df = pd.concat([df, cat_dummies], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-6d56baeac1ea> in <module>
#       1 #df = pd.concat([df, cat_dummies], axis=1)
# ----> 2 df["score_waisiii_iq_zscore_r5"].mean().astype('floating')
#
# AttributeError: 'float' object has no attribute 'astype'

# %%
X = df[['Stunting_Yes','age_m_r4','sexr1','Age_gap_r1','maternal_schooling_r1','no_of_household_members_r3','household_assets_index_r3'
]] ## X usually means our input variables (or independent variables)
y = df["score_waisiii_iq_zscore_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     score_waisiii_iq_zscore_r5   R-squared:                       0.365
# Model:                                    OLS   Adj. R-squared:                  0.364
# Method:                         Least Squares   F-statistic:                     484.9
# Date:                        Fri, 12 Mar 2021   Prob (F-statistic):               0.00
# Time:                                12:56:15   Log-Likelihood:                -6377.0
# No. Observations:                        5914   AIC:                         1.277e+04
# Df Residuals:                            5906   BIC:                         1.282e+04
# Df Model:                                   7
# Covariance Type:                    nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
X = df[['Stunting_Yes','age_m_r4','sexr1','Age_gap_r1','maternal_schooling_r1','no_of_household_members_r3','household_assets_index_r3'
]] ## X usually means our input variables (or independent variables)
y = df["Height_adult"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Height_adult   R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     816.1
# Date:                Fri, 12 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:56:31   Log-Likelihood:                -18543.
# No. Observations:                5914   AIC:                         3.710e+04
# Df Residuals:                    5906   BIC:                         3.715e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
X = df[['Stunting_Yes','age_m_r4','sexr1','Age_gap_r1','maternal_schooling_r1','no_of_household_members_r3','household_assets_index_r3'
]] ## X usually means our input variables (or independent variables)
y = df["schooling_y_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         schooling_y_r5   R-squared:                       0.401
# Model:                            OLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                     564.3
# Date:                Fri, 12 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:56:41   Log-Likelihood:                -14758.
# No. Observations:                5914   AIC:                         2.953e+04
# Df Residuals:                    5906   BIC:                         2.958e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
X = df[['Stunting','age_m_r4','sexr1','Age_gap_r1','maternal_schooling_r1','no_of_household_members_r3','household_assets_index_r3','schooling_y_r5'
]] ## X usually means our input variables (or independent variables)
y = df["ISIC labour categories_r5.1"] ## Y usually means our output/dependent variable
X = sm.add_constant(X, prepend = False)## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.Logit(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.502540
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 Logit Regression Results
# ...
# Dep. Variable:     ISIC labour categories_r5.1   No. Observations:                 1942
# Model:                                   Logit   Df Residuals:                     1933
# Method:                                    MLE   Df Model:                            8
# Date:                         Sun, 28 Feb 2021   Pseudo R-squ.:                 0.03386
# Time:                                 20:51:00   Log-Likelihood:                -975.93
# converged:                                True   LL-Null:                       -1010.1
# Covariance Type:                     nonrobust   LLR p-value:                 1.019e-11
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ...
