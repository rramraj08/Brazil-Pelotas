# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_brazil = pd.read_excel(r'alldatasets.xlsx',sheet_name='Brazil')

# %%
df_brazil.head()
# Out:
#   childid country  height  stunting_2cat  EDUYRS2   z_score  agegapr1  \
# 0     BR0  Brazil  180.65            0.0     13.0  1.510429       7.0
# 1     BR1  Brazil  180.35            0.0     16.0  0.399053       0.0
# 2     BR2  Brazil  164.95            0.0     15.0  0.002132       NaN
# 3     BR3  Brazil  182.30            0.0      4.0 -1.823701       NaN
# 4     BR4  Brazil     NaN            NaN      NaN       NaN       NaN
#
#    momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  job_cat  pvt_sector  \
# 0          8.0      1.0      47.0       4.0  0.882373      3.0         0.0
# 1          5.0      1.0      50.0       3.0  0.306352      3.0         1.0
# 2          5.0      0.0      52.0       3.0  0.533106      3.0         1.0
# 3          9.0      1.0      49.0       8.0  0.777917      NaN         NaN
# 4         15.0      1.0       NaN       NaN       NaN      NaN         NaN
#
#      earn_usd
# 0  707.225360
# 1  290.316010
# 2  109.973544
# 3    0.000000
# 4         NaN

# %%
df_brazil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5914 entries, 0 to 5913
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   childid        5914 non-null   object
#  1   country        5914 non-null   object
#  2   height         3607 non-null   float64
#  3   stunting_2cat  4742 non-null   float64
#  4   EDUYRS2        3635 non-null   float64
#  5   z_score        3611 non-null   float64
#  6   agegapr1       3469 non-null   float64
#  7   momeduyrsr1    5907 non-null   float64
#  8   chsexr1        5913 non-null   float64
#  9   agemonr1       4747 non-null   float64
#  10  hhsizer1       5007 non-null   float64
#  11  wi_newr1       4990 non-null   float64
#  12  job_cat        3017 non-null   float64
#  13  pvt_sector     2766 non-null   float64
#  14  earn_usd       3668 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 693.2+ KB

# %%
df_brazil.describe()
# Out:
#             height  stunting_2cat      EDUYRS2       z_score     agegapr1  \
# count  3607.000000    4742.000000  3635.000000  3.611000e+03  3469.000000
# mean    167.711076       0.109447    11.315268  1.218500e-11     4.560392
# std       9.213763       0.312233     4.162320  1.000138e+00     4.103920
# min     138.500000       0.000000     0.000000 -3.570150e+00     0.000000
# 25%     160.700000       0.000000     8.000000 -6.329400e-01     2.000000
# 50%     167.400000       0.000000    11.000000  2.132443e-03     4.000000
# 75%     174.600000       0.000000    14.000000  7.165889e-01     6.000000
# max     201.200000       1.000000    22.000000  2.780574e+00    31.000000
#
#        momeduyrsr1      chsexr1     agemonr1     hhsizer1     wi_newr1  \
# count  5907.000000  5913.000000  4747.000000  5007.000000  4990.000000
# mean      6.488573     0.513614    43.134401     4.684841     0.503139
# std       4.187285     0.499857     3.685779     2.033709     0.189250
# min       0.000000     0.000000    35.000000     0.000000     0.000000
# 25%       4.000000     0.000000    40.000000     3.000000     0.367876
# 50%       5.000000     1.000000    43.000000     4.000000     0.536873
# 75%       9.000000     1.000000    46.000000     5.000000     0.603284
# max      22.000000     1.000000    53.000000    61.000000     1.000000
#
#            job_cat   pvt_sector     earn_usd
# count  3017.000000  2766.000000  3668.000000
# mean      2.868744     0.866956   278.431375
# std       0.494003     0.339684   422.757290
# min       1.000000     0.000000     0.000000
# 25%       3.000000     1.000000    93.707360
# 50%       3.000000     1.000000   176.806340
# 75%       3.000000     1.000000   334.296587
# max       4.000000     1.000000  8840.317000

# %%
df_brazil=df_brazil.astype({"chsexr1": 'object', "job_cat": 'object', "pvt_sector": 'object',"stunting_2cat": 'object'})

# %%
df_brazil.dtypes
# Out:
# childid           object
# country           object
# height           float64
# stunting_2cat     object
# EDUYRS2          float64
# z_score          float64
# agegapr1         float64
# momeduyrsr1      float64
# chsexr1           object
# agemonr1         float64
# hhsizer1         float64
# wi_newr1         float64
# job_cat           object
# pvt_sector        object
# earn_usd         float64
# dtype: object

# %%
df_outlier=df_brazil.copy()

# %%
df_outlier.dtypes
# Out:
# childid           object
# country           object
# height           float64
# stunting_2cat     object
# EDUYRS2          float64
# z_score          float64
# agegapr1         float64
# momeduyrsr1      float64
# chsexr1           object
# agemonr1         float64
# hhsizer1         float64
# wi_newr1         float64
# job_cat           object
# pvt_sector        object
# earn_usd         float64
# dtype: object

# %%
total = df_outlier.isnull().sum().sort_values(ascending=False)
percent = (df_outlier.isnull().sum()/df_outlier.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Missing Percent'])
missing_data['Missing Percent'] = missing_data['Missing Percent'].apply(lambda x: x * 100)
missing_data.loc[missing_data['Missing Percent'] > 95]
# Out:
# Empty DataFrame
# Columns: [Total, Missing Percent]
# Index: []

# %%
df_outlier=df_outlier.select_dtypes(include=['int64','floating'])

# %%
df_outlier.dtypes
# Out:
# height         float64
# EDUYRS2        float64
# z_score        float64
# agegapr1       float64
# momeduyrsr1    float64
# agemonr1       float64
# hhsizer1       float64
# wi_newr1       float64
# earn_usd       float64
# dtype: object

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df_outlier.dtypes
# Out:
# height         float64
# EDUYRS2        float64
# z_score        float64
# agegapr1       float64
# momeduyrsr1    float64
# agemonr1       float64
# hhsizer1       float64
# wi_newr1       float64
# earn_usd       float64
# dtype: object

# %%
#sns.pairplot(df_outlier)

# %% [markdown]
# # Outlier Cappping

# %%
def cap_data(df):
    for col in df.columns:
        print("capping the ",col)
        if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64') | ((df[col].dtype)=='float32')):
            percentiles = df[col].quantile([0.01,0.99]).values
            df[col][df[col] <= percentiles[0]] = percentiles[0]
            df[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            df[col]=df[col]
    return df

# %%
final_df=cap_data(df_outlier)
# Out:
# capping the  height
# capping the  EDUYRS2
# capping the  z_score
# capping the  agegapr1
# capping the  momeduyrsr1
# capping the  agemonr1
# capping the  hhsizer1
# capping the  wi_newr1
# capping the  earn_usd

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

# %%
df_brazil=df_brazil.drop(['childid','country'],axis=1)

# %%
all_category_features=df_brazil.select_dtypes(include='object')

# %%
all_category_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5914 entries, 0 to 5913
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stunting_2cat  4742 non-null   object
#  1   chsexr1        5913 non-null   object
#  2   job_cat        3017 non-null   object
#  3   pvt_sector     2766 non-null   object
# dtypes: object(4)
# memory usage: 184.9+ KB

# %% [markdown]
# # KNN for Categories

# %%
mm = MinMaxScaler()

def find_category_mappings(df, variable):
    return {k: i for i, k in enumerate(df[variable].dropna().unique(), 0)}

def integer_encode(df , variable, ordinal_mapping):
    df[variable] = df[variable].map(ordinal_mapping)

mappin = dict()
def imputation(df1 , cols):
    df = df1.copy()
    #Encoding dict &amp; Removing nan    
    #mappin = dict()
    for variable in cols:
        mappings = find_category_mappings(df, variable)
        mappin[variable] = mappings

    #Apply mapping
    for variable in cols:
        integer_encode(df, variable, mappin[variable])  

    #Minmaxscaler and KNN imputation 
    sca = mm.fit_transform(df)
    knn_imputer = KNNImputer()
    knn = knn_imputer.fit_transform(sca)
    df.iloc[:,:] = mm.inverse_transform(knn)
    for i in df.columns : 
        df[i] = round(df[i]).astype('int')

    #Inverse transform
    for i in cols:
        inv_map = {v: k for k, v in mappin[i].items()}
        df[i] = df[i].map(inv_map)
    return df

# %%
df_cat_imp=imputation(all_category_features,['stunting_2cat','chsexr1','job_cat','pvt_sector'])

# %%
df_cat_imp.isnull().sum().sort_values(ascending = False)
# Out:
# pvt_sector       0
# job_cat          0
# chsexr1          0
# stunting_2cat    0
# dtype: int64

# %%
df_cat_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5914 entries, 0 to 5913
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stunting_2cat  5914 non-null   float64
#  1   chsexr1        5914 non-null   float64
#  2   job_cat        5914 non-null   float64
#  3   pvt_sector     5914 non-null   float64
# dtypes: float64(4)
# memory usage: 184.9 KB

# %%
#df_cat_imp.to_csv(r'C:\Users\rramr\OneDrive\Desktop\Modern Scientist Global\Peru\df_knn_before.csv', encoding='utf-8', index=True)

# %%
#all_category_features=df_et.select_dtypes(include='o')

# %%
#cat_dummies = pd.get_dummies(all_category_features, dummy_na=True)
#cat_dummies.head()

# %% [markdown]
# # KNN for numerics

# %%
df_knn=final_df.copy()

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df_num_imp = pd.DataFrame(imputer.fit_transform(df_knn),columns = df_knn.columns)

# %%
df_num_imp.head()
# Out:
#    height  EDUYRS2   z_score  agegapr1  momeduyrsr1  agemonr1  hhsizer1  \
# 0  180.65     13.0  1.510429       7.0          8.0      47.0       4.0
# 1  180.35     16.0  0.399053       0.0          5.0      50.0       3.0
# 2  164.95     15.0  0.002132       3.2          5.0      50.0       3.0
# 3  182.30      4.0 -1.823701       5.0          9.0      49.0       8.0
# 4  177.45     16.0  1.081756       6.2         15.0      45.6       3.6
#
#    wi_newr1    earn_usd
# 0  0.882373  707.225360
# 1  0.306352  290.316010
# 2  0.533106  109.973544
# 3  0.777917    0.000000
# 4  0.677364  432.998727

# %%
df_outlier_concat = pd.concat([df_num_imp, df_cat_imp], axis=1)
df_outlier_concat.head()
# Out:
#    height  EDUYRS2   z_score  agegapr1  momeduyrsr1  agemonr1  hhsizer1  \
# 0  180.65     13.0  1.510429       7.0          8.0      47.0       4.0
# 1  180.35     16.0  0.399053       0.0          5.0      50.0       3.0
# 2  164.95     15.0  0.002132       3.2          5.0      50.0       3.0
# 3  182.30      4.0 -1.823701       5.0          9.0      49.0       8.0
# 4  177.45     16.0  1.081756       6.2         15.0      45.6       3.6
#
#    wi_newr1    earn_usd  stunting_2cat  chsexr1  job_cat  pvt_sector
# 0  0.882373  707.225360            0.0      1.0      3.0         0.0
# 1  0.306352  290.316010            0.0      1.0      3.0         1.0
# 2  0.533106  109.973544            0.0      0.0      3.0         1.0
# 3  0.777917    0.000000            0.0      1.0      2.0         1.0
# 4  0.677364  432.998727            0.0      1.0      3.0         1.0

# %%
df_outlier_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5914 entries, 0 to 5913
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   height         5914 non-null   float64
#  1   EDUYRS2        5914 non-null   float64
#  2   z_score        5914 non-null   float64
#  3   agegapr1       5914 non-null   float64
#  4   momeduyrsr1    5914 non-null   float64
#  5   agemonr1       5914 non-null   float64
#  6   hhsizer1       5914 non-null   float64
#  7   wi_newr1       5914 non-null   float64
#  8   earn_usd       5914 non-null   float64
#  9   stunting_2cat  5914 non-null   float64
#  10  chsexr1        5914 non-null   float64
#  11  job_cat        5914 non-null   float64
#  12  pvt_sector     5914 non-null   float64
# dtypes: float64(13)
# memory usage: 600.8 KB

# %%
df_outlier_concat=df_outlier_concat.astype({"stunting_2cat": 'int64'})

# %%
df_outlier_concat.head()
# Out:
#    height  EDUYRS2   z_score  agegapr1  momeduyrsr1  agemonr1  hhsizer1  \
# 0  180.65     13.0  1.510429       7.0          8.0      47.0       4.0
# 1  180.35     16.0  0.399053       0.0          5.0      50.0       3.0
# 2  164.95     15.0  0.002132       3.2          5.0      50.0       3.0
# 3  182.30      4.0 -1.823701       5.0          9.0      49.0       8.0
# 4  177.45     16.0  1.081756       6.2         15.0      45.6       3.6
#
#    wi_newr1    earn_usd  stunting_2cat  chsexr1  job_cat  pvt_sector
# 0  0.882373  707.225360              0      1.0      3.0         0.0
# 1  0.306352  290.316010              0      1.0      3.0         1.0
# 2  0.533106  109.973544              0      0.0      3.0         1.0
# 3  0.777917    0.000000              0      1.0      2.0         1.0
# 4  0.677364  432.998727              0      1.0      3.0         1.0

# %%
df_knn_imp=df_outlier_concat.copy()

# %%
import statsmodels.api as sm

# %% [markdown]
# # cognition

# %%
#cognition

X = df_knn_imp["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df_knn_imp["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     188.5
# Date:                Wed, 28 Apr 2021   Prob (F-statistic):           2.97e-42
# Time:                        14:56:09   Log-Likelihood:                -7318.9
# No. Observations:                5914   AIC:                         1.464e+04
# Df Residuals:                    5912   BIC:                         1.466e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0441      0.011      3.886      0.000       0.022       0.066
# stunting_2cat    -0.5264      0.038    -13.730      0.000      -0.602      -0.451
# ==============================================================================
# Omnibus:                        0.841   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.657   Jarque-Bera (JB):                0.795
# Skew:                          -0.022   Prob(JB):                        0.672
# Kurtosis:                       3.036   Cond. No.                         3.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # height

# %%
#Height

X = df_knn_imp["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df_knn_imp["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     304.3
# Date:                Wed, 28 Apr 2021   Prob (F-statistic):           1.74e-66
# Time:                        14:56:38   Log-Likelihood:                -20164.
# No. Observations:                5914   AIC:                         4.033e+04
# Df Residuals:                    5912   BIC:                         4.035e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           168.1208      0.100   1686.641      0.000     167.925     168.316
# stunting_2cat    -5.8694      0.336    -17.444      0.000      -6.529      -5.210
# ==============================================================================
# Omnibus:                       40.113   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.854
# Skew:                           0.203   Prob(JB):                     1.35e-09
# Kurtosis:                       2.958   Cond. No.                         3.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # education

# %%
#education

X = df_knn_imp["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df_knn_imp["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     189.9
# Date:                Wed, 28 Apr 2021   Prob (F-statistic):           1.49e-42
# Time:                        14:57:15   Log-Likelihood:                -16011.
# No. Observations:                5914   AIC:                         3.203e+04
# Df Residuals:                    5912   BIC:                         3.204e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            11.4147      0.049    231.150      0.000      11.318      11.512
# stunting_2cat    -2.2974      0.167    -13.782      0.000      -2.624      -1.971
# ==============================================================================
# Omnibus:                       86.694   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.239
# Skew:                          -0.292   Prob(JB):                     4.19e-20
# Kurtosis:                       2.857   Cond. No.                         3.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # cognition covariates

# %%
X = df_knn_imp[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df_knn_imp["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     356.5
# Date:                Wed, 28 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:57:55   Log-Likelihood:                -6369.5
# No. Observations:                5914   AIC:                         1.276e+04
# Df Residuals:                    5906   BIC:                         1.281e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -1.4542      0.125    -11.657      0.000      -1.699      -1.210
# stunting_2cat    -0.1961      0.034     -5.810      0.000      -0.262      -0.130
# agemonr1          0.0173      0.003      6.283      0.000       0.012       0.023
# chsexr1           0.0621      0.019      3.353      0.001       0.026       0.098
# agegapr1         -0.0020      0.003     -0.716      0.474      -0.008       0.004
# momeduyrsr1       0.0766      0.003     27.905      0.000       0.071       0.082
# hhsizer1         -0.0488      0.006     -8.291      0.000      -0.060      -0.037
# wi_newr1          0.8559      0.063     13.596      0.000       0.733       0.979
# ==============================================================================
# Omnibus:                       45.812   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.005
# Skew:                          -0.049   Prob(JB):                     1.04e-15
# Kurtosis:                       3.520   Cond. No.                         598.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Height covariates

# %%
X = df_knn_imp[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df_knn_imp["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     428.3
# Date:                Wed, 28 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:58:26   Log-Likelihood:                -19099.
# No. Observations:                5914   AIC:                         3.821e+04
# Df Residuals:                    5906   BIC:                         3.827e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           161.0900      1.074    150.058      0.000     158.986     163.194
# stunting_2cat    -5.4195      0.290    -18.664      0.000      -5.989      -4.850
# agemonr1          0.0346      0.024      1.455      0.146      -0.012       0.081
# chsexr1           7.8599      0.159     49.325      0.000       7.547       8.172
# agegapr1         -0.0116      0.024     -0.478      0.633      -0.059       0.036
# momeduyrsr1       0.2216      0.024      9.376      0.000       0.175       0.268
# hhsizer1         -0.0266      0.051     -0.526      0.599      -0.126       0.073
# wi_newr1          0.4068      0.542      0.751      0.453      -0.655       1.469
# ==============================================================================
# Omnibus:                       45.096   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.815
# Skew:                           0.151   Prob(JB):                     2.26e-09
# Kurtosis:                       2.735   Cond. No.                         598.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # education covariates

# %%
X = df_knn_imp[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df_knn_imp["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.380
# Method:                 Least Squares   F-statistic:                     519.6
# Date:                Wed, 28 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:58:55   Log-Likelihood:                -14685.
# No. Observations:                5914   AIC:                         2.939e+04
# Df Residuals:                    5906   BIC:                         2.944e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             7.6002      0.509     14.932      0.000       6.602       8.598
# stunting_2cat    -0.6679      0.138     -4.851      0.000      -0.938      -0.398
# agemonr1          0.0101      0.011      0.897      0.370      -0.012       0.032
# chsexr1          -0.4883      0.076     -6.463      0.000      -0.636      -0.340
# agegapr1         -0.0068      0.012     -0.594      0.553      -0.029       0.016
# momeduyrsr1       0.3914      0.011     34.927      0.000       0.369       0.413
# hhsizer1         -0.2357      0.024     -9.822      0.000      -0.283      -0.189
# wi_newr1          4.1510      0.257     16.162      0.000       3.647       4.654
# ==============================================================================
# Omnibus:                      436.565   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              813.405
# Skew:                          -0.526   Prob(JB):                    2.35e-177
# Kurtosis:                       4.481   Cond. No.                         598.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
