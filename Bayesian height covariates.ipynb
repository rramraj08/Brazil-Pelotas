# %%
import pandas as pd
import numpy as np
import arviz as az

# %%
df_brazil = pd.read_excel(r'alldatasets.xlsx',sheet_name='Brazil')

# %%
df_brazil.head()
# Out:
#   childid country  height  stunting_2cat  EDUYRS2   z_score  agegapr1  \
# 0     BR0  Brazil  180.65            0.0     13.0  1.510429       7.0
# 1     BR1  Brazil  180.35            0.0     16.0  0.399053       0.0
# 2     BR2  Brazil  164.95            0.0     15.0  0.002132       NaN
# 3     BR3  Brazil  182.30            0.0      4.0 -1.823701       NaN
# 4     BR4  Brazil     NaN            NaN      NaN       NaN       NaN
#
#    momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  job_cat  pvt_sector  \
# 0          8.0      1.0      47.0       4.0  0.882373      3.0         0.0
# 1          5.0      1.0      50.0       3.0  0.306352      3.0         1.0
# 2          5.0      0.0      52.0       3.0  0.533106      3.0         1.0
# 3          9.0      1.0      49.0       8.0  0.777917      NaN         NaN
# 4         15.0      1.0       NaN       NaN       NaN      NaN         NaN
#
#      earn_usd
# 0  707.225360
# 1  290.316010
# 2  109.973544
# 3    0.000000
# 4         NaN

# %%
df_brazil.columns
# Out:
# Index(['childid', 'country', 'height', 'stunting_2cat', 'EDUYRS2', 'z_score',
#        'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1', 'hhsizer1',
#        'wi_newr1', 'job_cat', 'pvt_sector', 'earn_usd'],
#       dtype='object')

# %%
from scipy import stats
import scipy.stats as stats

# %%
import seaborn as sns
sns.displot(df_brazil, x="height", hue="stunting_2cat", kind="kde", multiple="stack")

# %%
df_brazil=df_brazil.astype({"chsexr1": 'object', "job_cat": 'object', "pvt_sector": 'object',"stunting_2cat": 'object'})

# %%
df_outlier=df_brazil.copy()

# %%
total = df_outlier.isnull().sum().sort_values(ascending=False)
percent = (df_outlier.isnull().sum()/df_outlier.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Missing Percent'])
missing_data['Missing Percent'] = missing_data['Missing Percent'].apply(lambda x: x * 100)
missing_data.loc[missing_data['Missing Percent'] > 95]
# Out:
# Empty DataFrame
# Columns: [Total, Missing Percent]
# Index: []

# %%
df_outlier=df_outlier.select_dtypes(include=['int64','floating'])

# %%
df_outlier.dtypes
# Out:
# height         float64
# EDUYRS2        float64
# z_score        float64
# agegapr1       float64
# momeduyrsr1    float64
# agemonr1       float64
# hhsizer1       float64
# wi_newr1       float64
# earn_usd       float64
# dtype: object

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df_outlier.dtypes
# Out:
# height         float64
# EDUYRS2        float64
# z_score        float64
# agegapr1       float64
# momeduyrsr1    float64
# agemonr1       float64
# hhsizer1       float64
# wi_newr1       float64
# earn_usd       float64
# dtype: object

# %%
def cap_data(df):
    for col in df.columns:
        print("capping the ",col)
        if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64') | ((df[col].dtype)=='float32')):
            percentiles = df[col].quantile([0.01,0.99]).values
            df[col][df[col] <= percentiles[0]] = percentiles[0]
            df[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            df[col]=df[col]
    return df

# %%
final_df=cap_data(df_outlier)
# Out:
# capping the  height
# capping the  EDUYRS2
# capping the  z_score
# capping the  agegapr1
# capping the  momeduyrsr1
# capping the  agemonr1
# capping the  hhsizer1
# capping the  wi_newr1
# capping the  earn_usd

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

# %%
df_brazil=df_brazil.drop(['childid','country'],axis=1)

# %%
all_category_features=df_brazil.select_dtypes(include='object')

# %%
all_category_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5914 entries, 0 to 5913
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stunting_2cat  4742 non-null   object
#  1   chsexr1        5913 non-null   object
#  2   job_cat        3017 non-null   object
#  3   pvt_sector     2766 non-null   object
# dtypes: object(4)
# memory usage: 184.9+ KB

# %% [markdown]
# # KNN for Categories

# %%
mm = MinMaxScaler()

def find_category_mappings(df, variable):
    return {k: i for i, k in enumerate(df[variable].dropna().unique(), 0)}

def integer_encode(df , variable, ordinal_mapping):
    df[variable] = df[variable].map(ordinal_mapping)

mappin = dict()
def imputation(df1 , cols):
    df = df1.copy()
    #Encoding dict &amp; Removing nan    
    #mappin = dict()
    for variable in cols:
        mappings = find_category_mappings(df, variable)
        mappin[variable] = mappings

    #Apply mapping
    for variable in cols:
        integer_encode(df, variable, mappin[variable])  

    #Minmaxscaler and KNN imputation 
    sca = mm.fit_transform(df)
    knn_imputer = KNNImputer()
    knn = knn_imputer.fit_transform(sca)
    df.iloc[:,:] = mm.inverse_transform(knn)
    for i in df.columns : 
        df[i] = round(df[i]).astype('int')

    #Inverse transform
    for i in cols:
        inv_map = {v: k for k, v in mappin[i].items()}
        df[i] = df[i].map(inv_map)
    return df

# %%
df_cat_imp=imputation(all_category_features,['stunting_2cat','chsexr1','job_cat','pvt_sector'])

# %%
df_cat_imp.isnull().sum().sort_values(ascending = False)
# Out:
# pvt_sector       0
# job_cat          0
# chsexr1          0
# stunting_2cat    0
# dtype: int64

# %%
df_cat_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5914 entries, 0 to 5913
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stunting_2cat  5914 non-null   float64
#  1   chsexr1        5914 non-null   float64
#  2   job_cat        5914 non-null   float64
#  3   pvt_sector     5914 non-null   float64
# dtypes: float64(4)
# memory usage: 184.9 KB

# %% [markdown]
# # KNN for numerics

# %%
df_knn=final_df.copy()

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df_num_imp = pd.DataFrame(imputer.fit_transform(df_knn),columns = df_knn.columns)

# %%
df_num_imp.head()
# Out:
#    height  EDUYRS2   z_score  agegapr1  momeduyrsr1  agemonr1  hhsizer1  \
# 0  180.65     13.0  1.510429       7.0          8.0      47.0       4.0
# 1  180.35     16.0  0.399053       0.0          5.0      50.0       3.0
# 2  164.95     15.0  0.002132       3.2          5.0      50.0       3.0
# 3  182.30      4.0 -1.823701       5.0          9.0      49.0       8.0
# 4  177.45     16.0  1.081756       6.2         15.0      45.6       3.6
#
#    wi_newr1    earn_usd
# 0  0.882373  707.225360
# 1  0.306352  290.316010
# 2  0.533106  109.973544
# 3  0.777917    0.000000
# 4  0.677364  432.998727

# %%
df_outlier_concat = pd.concat([df_num_imp, df_cat_imp], axis=1)
df_outlier_concat.head()
# Out:
#    height  EDUYRS2   z_score  agegapr1  momeduyrsr1  agemonr1  hhsizer1  \
# 0  180.65     13.0  1.510429       7.0          8.0      47.0       4.0
# 1  180.35     16.0  0.399053       0.0          5.0      50.0       3.0
# 2  164.95     15.0  0.002132       3.2          5.0      50.0       3.0
# 3  182.30      4.0 -1.823701       5.0          9.0      49.0       8.0
# 4  177.45     16.0  1.081756       6.2         15.0      45.6       3.6
#
#    wi_newr1    earn_usd  stunting_2cat  chsexr1  job_cat  pvt_sector
# 0  0.882373  707.225360            0.0      1.0      3.0         0.0
# 1  0.306352  290.316010            0.0      1.0      3.0         1.0
# 2  0.533106  109.973544            0.0      0.0      3.0         1.0
# 3  0.777917    0.000000            0.0      1.0      2.0         1.0
# 4  0.677364  432.998727            0.0      1.0      3.0         1.0

# %%
df_outlier_concat=df_outlier_concat.astype({"stunting_2cat": 'int64'})

# %%
df_outlier_concat.head()
# Out:
#    height  EDUYRS2   z_score  agegapr1  momeduyrsr1  agemonr1  hhsizer1  \
# 0  180.65     13.0  1.510429       7.0          8.0      47.0       4.0
# 1  180.35     16.0  0.399053       0.0          5.0      50.0       3.0
# 2  164.95     15.0  0.002132       3.2          5.0      50.0       3.0
# 3  182.30      4.0 -1.823701       5.0          9.0      49.0       8.0
# 4  177.45     16.0  1.081756       6.2         15.0      45.6       3.6
#
#    wi_newr1    earn_usd  stunting_2cat  chsexr1  job_cat  pvt_sector
# 0  0.882373  707.225360              0      1.0      3.0         0.0
# 1  0.306352  290.316010              0      1.0      3.0         1.0
# 2  0.533106  109.973544              0      0.0      3.0         1.0
# 3  0.777917    0.000000              0      1.0      2.0         1.0
# 4  0.677364  432.998727              0      1.0      3.0         1.0

# %%
df_knn_imp=df_outlier_concat.copy()

# %% [markdown]
# # Bayesian

# %%
Y = df_knn_imp['height']
X = df_knn_imp[['stunting_2cat', 'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1','wi_newr1',
       'hhsizer1']]

# %%
import pymc3 as pm

with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 168.7, sd = 10)
    
    # Slope 
    stunting_2cat = pm.Normal('stunting_2cat', mu = 1, sd = 7.8)
    agemonr1        = pm.Normal('agemonr1', mu = 1, sd = 7.8)  
    chsexr1       = pm.Normal('chsexr1', mu = 1, sd = 7.8)  
    agegapr1        = pm.Normal('agegapr1', mu = 1, sd = 7.8)   
    momeduyrsr1     = pm.Normal('momeduyrsr1', mu = 1, sd = 7.8)  
    hhsizer1        = pm.Normal('hhsizer1', mu = 1, sd = 7.8)  
    wi_newr1        = pm.Normal('wi_newr1', mu = 1, sd = 7.8)
   
    
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 10)
    
    # Estimate of mean
    mean = intercept + stunting_2cat * X.loc[:, 'stunting_2cat'] + agemonr1 * X.loc[:, 'agemonr1'] +     chsexr1 * X.loc[:, 'chsexr1'] +  agegapr1 * X.loc[:, 'agegapr1'] +  momeduyrsr1 * X.loc[:, 'momeduyrsr1']     +  hhsizer1 * X.loc[:, 'hhsizer1'] +  wi_newr1 * X.loc[:, 'wi_newr1'] 


    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = Y.values)
    
    # Sampler
    step = pm.NUTS(target_accept=0.95)

    # Posterior distribution
    linear_trace = pm.sample(16000, step)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-36cf3388de4a> in <module>
#      25
#      26     # Observed values
# ---> 27     Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = Y.values)
#      28
#      29     # Sampler
#
# ~\Anaconda4\lib\site-packages\pymc3\distributions\distribution.py in __new__(cls, name, *args, **kwargs)
#     120         else:
#     121             dist = cls.dist(*args, **kwargs)
# --> 122         return model.Var(name, dist, data, total_size, dims=dims)
#     123
#     124     def __getnewargs__(self):
#
# ~\Anaconda4\lib\site-packages\pymc3\model.py in Var(self, name, dist, data, total_size, dims)
#    1174         else:
#    1175             with self:
# -> 1176                 var = ObservedRV(
#    1177                     name=name,
#    1178                     data=data,
#
# ~\Anaconda4\lib\site-packages\pymc3\model.py in __init__(self, type, owner, index, name, data, distribution, total_size, model)
#    1825
#    1826             self.missing_values = data.missing_values
# -> 1827             self.logp_elemwiset = distribution.logp(data)
#    1828             # The logp might need scaling in minibatches.
#    1829             # This is done in `Factor`.
#
# ~\Anaconda4\lib\site-packages\pymc3\distributions\continuous.py in logp(self, value)
#     533         mu = self.mu
#     534
# --> 535         return bound((-tau * (value - mu) ** 2 + tt.log(tau / np.pi / 2.0)) / 2.0, sigma > 0)
#     536
#     537     def _distr_parameters_for_repr(self):
#
# ~\Anaconda4\lib\site-packages\theano\tensor\var.py in __sub__(self, other)
#     118         # and the return value in that case
#     119         try:
# --> 120             return theano.tensor.basic.sub(self, other)
#     121         except (NotImplementedError, TypeError):
#     122             return NotImplemented
#
# ~\Anaconda4\lib\site-packages\theano\graph\op.py in __call__(self, *inputs, **kwargs)
#     251
#     252         if config.compute_test_value != "off":
# --> 253             compute_test_value(node)
#     254
#     255         if self.default_output is not None:
#
# ~\Anaconda4\lib\site-packages\theano\graph\op.py in compute_test_value(node)
#     124
#     125     # Create a thunk that performs the computation
# --> 126     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#     127     thunk.inputs = [storage_map[v] for v in node.inputs]
#     128     thunk.outputs = [storage_map[v] for v in node.outputs]
#
# ~\Anaconda4\lib\site-packages\theano\graph\op.py in make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     632             )
#     633             try:
# --> 634                 return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#     635             except (NotImplementedError, MethodNotDefined):
#     636                 # We requested the c code, so don't catch the error.
#
# ~\Anaconda4\lib\site-packages\theano\graph\op.py in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     598                 print(f"Disabling C code for {self} due to unsupported float16")
#     599                 raise NotImplementedError("float16")
# --> 600         outputs = cl.make_thunk(
#     601             input_storage=node_input_storage, output_storage=node_output_storage
#     602         )
#
# ~\Anaconda4\lib\site-packages\theano\link\c\basic.py in make_thunk(self, input_storage, output_storage, storage_map)
#    1201         """
#    1202         init_tasks, tasks = self.get_init_tasks()
# -> 1203         cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1204             input_storage, output_storage, storage_map
#    1205         )
#
# ~\Anaconda4\lib\site-packages\theano\link\c\basic.py in __compile__(self, input_storage, output_storage, storage_map)
#    1136         input_storage = tuple(input_storage)
#    1137         output_storage = tuple(output_storage)
# -> 1138         thunk, module = self.cthunk_factory(
#    1139             error_storage,
#    1140             input_storage,
#
# ~\Anaconda4\lib\site-packages\theano\link\c\basic.py in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map)
#    1632             for node in self.node_order:
#    1633                 node.op.prepare_node(node, storage_map, None, "c")
# -> 1634             module = get_module_cache().module_from_key(key=key, lnk=self)
#    1635
#    1636         vars = self.inputs + self.outputs + self.orphans
#
# ~\Anaconda4\lib\site-packages\theano\link\c\cmodule.py in module_from_key(self, key, lnk)
#    1189             try:
#    1190                 location = dlimport_workdir(self.dirname)
# -> 1191                 module = lnk.compile_cmodule(location)
#    1192                 name = module.__file__
#    1193                 assert name.startswith(location)
#
# ~\Anaconda4\lib\site-packages\theano\link\c\basic.py in compile_cmodule(self, location)
#    1541             try:
#    1542                 _logger.debug(f"LOCATION {location}")
# -> 1543                 module = c_compiler.compile_str(
#    1544                     module_name=mod.code_hash,
#    1545                     src_code=src_code,
#
# ~\Anaconda4\lib\site-packages\theano\link\c\cmodule.py in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2494
#    2495         try:
# -> 2496             p_out = output_subprocess_Popen(cmd)
#    2497             compile_stderr = p_out[1].decode()
#    2498         except Exception:
#
# ~\Anaconda4\lib\site-packages\theano\utils.py in output_subprocess_Popen(command, **params)
#     252     # we need to use communicate to make sure we don't deadlock around
#     253     # the stdout/stderr pipe.
# --> 254     out = p.communicate()
#     255     return out + (p.returncode,)
#     256
#
# ~\Anaconda4\lib\subprocess.py in communicate(self, input, timeout)
#    1022
#    1023             try:
# -> 1024                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1025             except KeyboardInterrupt:
#    1026                 # https://bugs.python.org/issue25942
#
# ~\Anaconda4\lib\subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1393             # calls communicate again.
#    1394             if self.stdout is not None:
# -> 1395                 self.stdout_thread.join(self._remaining_time(endtime))
#    1396                 if self.stdout_thread.is_alive():
#    1397                     raise TimeoutExpired(self.args, orig_timeout)
#
# ~\Anaconda4\lib\threading.py in join(self, timeout)
#    1009
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#    1013             # the behavior of a negative timeout isn't documented, but
#
# ~\Anaconda4\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1025         if lock is None:  # already determined that the C code is done
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#    1029             self._stop()
#
# KeyboardInterrupt:

# %%
az.summary(linear_trace)
# Out:
#                   mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_mean  \
# Intercept      161.177  1.069  159.161  163.196      0.006    0.004   33283.0
# stunting_2cat   -5.414  0.289   -5.944   -4.858      0.001    0.001   60413.0
# agemonr1         0.033  0.024   -0.011    0.078      0.000    0.000   34295.0
# chsexr1          7.855  0.159    7.561    8.160      0.001    0.000   62385.0
# agegapr1        -0.012  0.024   -0.058    0.033      0.000    0.000   54647.0
# momeduyrsr1      0.221  0.024    0.177    0.266      0.000    0.000   43778.0
# hhsizer1        -0.028  0.051   -0.123    0.068      0.000    0.000   51836.0
# wi_newr1         0.405  0.540   -0.615    1.413      0.003    0.002   41994.0
# sigma            6.118  0.056    6.012    6.224      0.000    0.000   54353.0
#
#                 ess_sd  ess_bulk  ess_tail  r_hat
# Intercept      33282.0   33278.0   37973.0    1.0
# stunting_2cat  60202.0   60425.0   47966.0    1.0
# agemonr1       33359.0   34297.0   39188.0    1.0
# chsexr1        62370.0   62375.0   47560.0    1.0
# agegapr1       36981.0   54624.0   45312.0    1.0
# momeduyrsr1    43732.0   43786.0   44881.0    1.0
# hhsizer1       41482.0   51838.0   47528.0    1.0
# wi_newr1       39430.0   41993.0   45087.0    1.0
# sigma          54337.0   54366.0   44299.0    1.0

# %%
az.plot_trace(linear_trace)
# Out:
# array([[<AxesSubplot:title={'center':'Intercept'}>,
#         <AxesSubplot:title={'center':'Intercept'}>],
#        [<AxesSubplot:title={'center':'stunting_2cat'}>,
#         <AxesSubplot:title={'center':'stunting_2cat'}>],
#        [<AxesSubplot:title={'center':'agemonr1'}>,
#         <AxesSubplot:title={'center':'agemonr1'}>],
#        [<AxesSubplot:title={'center':'chsexr1'}>,
#         <AxesSubplot:title={'center':'chsexr1'}>],
#        [<AxesSubplot:title={'center':'agegapr1'}>,
#         <AxesSubplot:title={'center':'agegapr1'}>],
#        [<AxesSubplot:title={'center':'momeduyrsr1'}>,
#         <AxesSubplot:title={'center':'momeduyrsr1'}>],
#        [<AxesSubplot:title={'center':'hhsizer1'}>,
#         <AxesSubplot:title={'center':'hhsizer1'}>],
#        [<AxesSubplot:title={'center':'wi_newr1'}>,
#         <AxesSubplot:title={'center':'wi_newr1'}>],
#        [<AxesSubplot:title={'center':'sigma'}>,
#         <AxesSubplot:title={'center':'sigma'}>]], dtype=object)

# %%
az.plot_forest(linear_trace);
