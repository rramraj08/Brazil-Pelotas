# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\rramr\OneDrive\Desktop\Modern Scientist Global\dataset\renamedfeb21.xlsx')

# %%
df.head()
# Out:
#    id                 status_1983                 status_1984  \
# 0   0     with weight information     with weight information
# 1   1  without weight information     with weight information
# 2   2     with weight information     with weight information
# 3   3     with weight information     with weight information
# 4   4  without weight information  without weight information
#
#                   status_1986 status_201213   sexr1 maternal_skin_color_r1  \
# 0     with weight information           Yes    Male                  black
# 1     with weight information           Yes    Male                  black
# 2     with weight information           Yes  Female                  white
# 3     with weight information           Yes    Male                  black
# 4  without weight information            No    Male                  white
#
#    maternal_schooling_r1 monthly_family_income_mw_1_r1  \
# 0                    8.0                      1.1 to 3
# 1                    5.0                      1.1 to 3
# 2                    5.0                      1.1 to 3
# 3                    9.0                     1 or less
# 4                   15.0                            10
#
#    monthly_family_income_q_r1  ...  separate_freezer_refrigerator_freezer_r5  \
# 0                           3  ...                                       Yes
# 1                           2  ...                                       Yes
# 2                           3  ...                                       Yes
# 3                           2  ...                                        No
# 4                           5  ...                                       NaN
#
#   no_of_bathrooms_r5  no_of_bathroom_shower_r5  pieces_for_sleep_r5  \
# 0                1.0                       1.0                  2.0
# 1                1.0                       1.0                  2.0
# 2                1.0                       1.0                  2.0
# 3                1.0                       1.0                  3.0
# 4                NaN                       NaN                  NaN
#
#      employment_sector_r5        type_of_job_r5  \
# 0          navy military        administrative
# 1  public road transport            bus driver
# 2          dental center   auxiliary secretary
# 3                     NaN                   NaN
# 4                     NaN                   NaN
#
#                            ISIC labour categories_r5  \
# 0  Public administration and defence; compulsory ...
# 1                         Transportation and storage
# 2      Administrative and support service activities
# 3                                                NaN
# 4                                                NaN
#
#    ISIC labour categories_r5.1  Paternal_age_2004  Age_at_2004_5
# 0                          1.0               56.0      23.008898
# 1                          0.0               39.0      23.285421
# 2                          1.0                NaN            NaN
# 3                          NaN                NaN            NaN
# 4                          NaN                NaN            NaN
#
# [5 rows x 286 columns]

# %%
from scipy import stats
import scipy.stats as stats

# %%
df['score_waisiii_iq_zscore_r5']=stats.zscore(df.score_waisiii_iq_r5,nan_policy='omit')

# %%
df.head()
# Out:
#    id                 status_1983                 status_1984  \
# 0   0     with weight information     with weight information
# 1   1  without weight information     with weight information
# 2   2     with weight information     with weight information
# 3   3     with weight information     with weight information
# 4   4  without weight information  without weight information
#
#                   status_1986 status_201213   sexr1 maternal_skin_color_r1  \
# 0     with weight information           Yes    Male                  black
# 1     with weight information           Yes    Male                  black
# 2     with weight information           Yes  Female                  white
# 3     with weight information           Yes    Male                  black
# 4  without weight information            No    Male                  white
#
#    maternal_schooling_r1 monthly_family_income_mw_1_r1  \
# 0                    8.0                      1.1 to 3
# 1                    5.0                      1.1 to 3
# 2                    5.0                      1.1 to 3
# 3                    9.0                     1 or less
# 4                   15.0                            10
#
#    monthly_family_income_q_r1  ...  no_of_bathrooms_r5  \
# 0                           3  ...                 1.0
# 1                           2  ...                 1.0
# 2                           3  ...                 1.0
# 3                           2  ...                 1.0
# 4                           5  ...                 NaN
#
#   no_of_bathroom_shower_r5  pieces_for_sleep_r5    employment_sector_r5  \
# 0                      1.0                  2.0          navy military
# 1                      1.0                  2.0  public road transport
# 2                      1.0                  2.0          dental center
# 3                      1.0                  3.0                     NaN
# 4                      NaN                  NaN                     NaN
#
#          type_of_job_r5                          ISIC labour categories_r5  \
# 0       administrative   Public administration and defence; compulsory ...
# 1           bus driver                          Transportation and storage
# 2  auxiliary secretary       Administrative and support service activities
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
#
#    ISIC labour categories_r5.1  Paternal_age_2004  Age_at_2004_5  \
# 0                          1.0               56.0      23.008898
# 1                          0.0               39.0      23.285421
# 2                          1.0                NaN            NaN
# 3                          NaN                NaN            NaN
# 4                          NaN                NaN            NaN
#
#    score_waisiii_iq_zscore_r5
# 0                    1.510429
# 1                    0.399053
# 2                    0.002132
# 3                   -1.823701
# 4                         NaN
#
# [5 rows x 287 columns]

# %%
import statsmodels.api as sm

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["score_waisiii_iq_zscore_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     score_waisiii_iq_zscore_r5   R-squared:                       0.040
# Model:                                    OLS   Adj. R-squared:                  0.040
# Method:                         Least Squares   F-statistic:                     135.8
# Date:                        Sun, 28 Feb 2021   Prob (F-statistic):           9.03e-31
# Time:                                10:30:12   Log-Likelihood:                -4535.0
# No. Observations:                        3239   AIC:                             9074.
# Df Residuals:                            3237   BIC:                             9086.
# Df Model:                                   1
# Covariance Type:                    nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0704      0.018      3.862      0.000       0.035       0.106
# Stunting      -0.6583      0.056    -11.653      0.000      -0.769      -0.548
# ==============================================================================
# Omnibus:                       12.068   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.779
# Skew:                          -0.050   Prob(JB):                      0.00752
# Kurtosis:                       2.750   Cond. No.                         3.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["schooling_y_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         schooling_y_r5   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     151.1
# Date:                Sun, 28 Feb 2021   Prob (F-statistic):           5.69e-34
# Time:                        10:30:24   Log-Likelihood:                -9196.3
# No. Observations:                3261   AIC:                         1.840e+04
# Df Residuals:                    3259   BIC:                         1.841e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.6515      0.075    154.877      0.000      11.504      11.799
# Stunting      -2.8345      0.231    -12.291      0.000      -3.287      -2.382
# ==============================================================================
# Omnibus:                       78.277   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.725
# Skew:                          -0.375   Prob(JB):                     1.79e-18
# Kurtosis:                       2.799   Cond. No.                         3.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["cohort_member_monthly_income_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     cohort_member_monthly_income_r5   R-squared:                       0.010
# Model:                                         OLS   Adj. R-squared:                  0.010
# Method:                              Least Squares   F-statistic:                     33.26
# Date:                             Sun, 28 Feb 2021   Prob (F-statistic):           8.82e-09
# Time:                                     10:30:26   Log-Likelihood:                -30285.
# No. Observations:                             3292   AIC:                         6.057e+04
# Df Residuals:                                 3290   BIC:                         6.059e+04
# Df Model:                                        1
# Covariance Type:                         nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1647.7168     44.156     37.316      0.000    1561.140    1734.293
# Stunting    -779.8592    135.229     -5.767      0.000   -1045.000    -514.718
# ==============================================================================
# Omnibus:                     4445.669   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1404976.515
# Skew:                           7.503   Prob(JB):                         0.00
# Kurtosis:                     103.088   Cond. No.                         3.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["amount_recived_in_reais_last_month_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     amount_recived_in_reais_last_month_r5   R-squared:                       0.006
# Model:                                               OLS   Adj. R-squared:                  0.005
# Method:                                    Least Squares   F-statistic:                     14.62
# Date:                                   Sun, 28 Feb 2021   Prob (F-statistic):           0.000135
# Time:                                           11:35:37   Log-Likelihood:                -24589.
# No. Observations:                                   2559   AIC:                         4.918e+04
# Df Residuals:                                       2557   BIC:                         4.919e+04
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2162.2687     74.832     28.895      0.000    2015.531    2309.007
# Stunting    -940.1843    245.895     -3.824      0.000   -1422.359    -458.010
# ==============================================================================
# Omnibus:                     4518.489   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5147916.835
# Skew:                          12.323   Prob(JB):                         0.00
# Kurtosis:                     221.342   Cond. No.                         3.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["ISIC labour categories_r5.1"] ## Y usually means our output/dependent variable
X = sm.add_constant(X, prepend = False)## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.Logit(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.513654
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 Logit Regression Results
# =======================================================================================
# Dep. Variable:     ISIC labour categories_r5.1   No. Observations:                 2693
# Model:                                   Logit   Df Residuals:                     2691
# Method:                                    MLE   Df Model:                            1
# Date:                         Sun, 28 Feb 2021   Pseudo R-squ.:               8.091e-05
# Time:                                 11:56:51   Log-Likelihood:                -1383.3
# converged:                                True   LL-Null:                       -1383.4
# Covariance Type:                     nonrobust   LLR p-value:                    0.6361
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Stunting      -0.0772      0.164     -0.470      0.638      -0.399       0.244
# const         -1.3189      0.050    -26.560      0.000      -1.416      -1.222
# ==============================================================================
# """

# %%
X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["worked_and_paid_r5.1"] ## Y usually means our output/dependent variable
X = sm.add_constant(X, prepend = False)## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.MNLogit(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.430849
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            MNLogit Regression Results
# ================================================================================
# Dep. Variable:     worked_and_paid_r5.1   No. Observations:                 4742
# Model:                          MNLogit   Df Residuals:                     4740
# Method:                             MLE   Df Model:                            1
# Date:                  Sun, 28 Feb 2021   Pseudo R-squ.:                  0.3722
# Time:                          12:04:12   Log-Likelihood:                -2043.1
# converged:                         True   LL-Null:                       -3254.5
# Covariance Type:              nonrobust   LLR p-value:                     0.000
# ============================================================================================
# worked_and_paid_r5.1=Yes       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Stunting                    -0.3637      0.093     -3.902      0.000      -0.546      -0.181
# const                        0.2750      0.031      8.851      0.000       0.214       0.336
# ============================================================================================
# """

# %%
import warnings

warnings.filterwarnings('ignore')

X = df["Stunting"] ## X usually means our input variables (or independent variables)
y = df["type_of_employment_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X, prepend = False)## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.MNLogit(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.403361
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             MNLogit Regression Results
# =================================================================================
# Dep. Variable:     type_of_employment_r5   No. Observations:                 4742
# Model:                           MNLogit   Df Residuals:                     4736
# Method:                              MLE   Df Model:                            3
# Date:                   Sun, 28 Feb 2021   Pseudo R-squ.:                  0.1359
# Time:                           12:07:23   Log-Likelihood:                -1912.7
# converged:                         False   LL-Null:                       -2213.6
# Covariance Type:               nonrobust   LLR p-value:                4.065e-130
# =================================================================================================================
#                   type_of_employment_r5=Employer       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Stunting                                            -0.7817      0.463     -1.690      0.091      -1.688       0.125
# const                                               -3.7336      0.108    -34.415      0.000      -3.946      -3.521
# --------------------------------------------------------------------------------------------------------------------
# type_of_employment_r5=Self-employed / Autonomous       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Stunting                                            -0.0643      0.149     -0.432      0.665      -0.355       0.227
# const                                               -2.0174      0.048    -41.696      0.000      -2.112      -1.923
# --------------------------------------------------------------------------------------------------------------------
# type_of_employment_r5=Study / paid internship       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Stunting                                        -18.7319   9143.970     -0.002      0.998   -1.79e+04    1.79e+04
# const                                            -5.6345      0.278    -20.279      0.000      -6.179      -5.090
# =================================================================================================================
# """

# %%
#cats=df['sexr1']

# %%
#cat_dummies = pd.get_dummies(data=cats, drop_first=True,dummy_na=True)

# %%
#df = pd.concat([df, cat_dummies], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-6d56baeac1ea> in <module>
#       1 #df = pd.concat([df, cat_dummies], axis=1)
# ----> 2 df["score_waisiii_iq_zscore_r5"].mean().astype('floating')
#
# AttributeError: 'float' object has no attribute 'astype'

# %%
X = df[['Stunting','age_m_r4','sexr1','Age_gap_r1','maternal_schooling_r1','no_of_household_members_r3','household_assets_index_r3','schooling_y_r5'
]] ## X usually means our input variables (or independent variables)
y = df["score_waisiii_iq_zscore_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     score_waisiii_iq_zscore_r5   R-squared:                       0.445
# Model:                                    OLS   Adj. R-squared:                  0.443
# Method:                         Least Squares   F-statistic:                     231.4
# Date:                        Sun, 28 Feb 2021   Prob (F-statistic):          1.80e-288
# Time:                                20:50:00   Log-Likelihood:                -2566.8
# No. Observations:                        2316   AIC:                             5152.
# Df Residuals:                            2307   BIC:                             5203.
# Df Model:                                   8
# Covariance Type:                    nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -2.6418      0.191    -13.808      0.000      -3.017      -2.267
# Stunting                      -0.1694      0.054     -3.166      0.002      -0.274      -0.064
# age_m_r4                       0.0182      0.004      4.375      0.000       0.010       0.026
# sexr1                          0.2030      0.031      6.566      0.000       0.142       0.264
# Age_gap_r1                     0.0053      0.003      1.825      0.068      -0.000       0.011
# maternal_schooling_r1          0.0275      0.005      5.945      0.000       0.018       0.037
# no_of_household_members_r3    -0.0338      0.009     -3.691      0.000      -0.052      -0.016
# household_assets_index_r3      0.0943      0.016      5.901      0.000       0.063       0.126
# schooling_y_r5                 0.1254      0.005     26.757      0.000       0.116       0.135
# ==============================================================================
# Omnibus:                        4.438   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.109   Jarque-Bera (JB):                4.619
# Skew:                          -0.064   Prob(JB):                       0.0993
# Kurtosis:                       3.177   Cond. No.                         576.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = df[['Stunting','age_m_r4','sexr1','Age_gap_r1','maternal_schooling_r1','no_of_household_members_r3','household_assets_index_r3','schooling_y_r5'
]] ## X usually means our input variables (or independent variables)
y = df["grade_year_r5"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          grade_year_r5   R-squared:                       0.183
# Model:                            OLS   Adj. R-squared:                  0.179
# Method:                 Least Squares   F-statistic:                     48.79
# Date:                Sun, 28 Feb 2021   Prob (F-statistic):           2.25e-71
# Time:                        20:49:37   Log-Likelihood:                -3680.8
# No. Observations:                1752   AIC:                             7380.
# Df Residuals:                    1743   BIC:                             7429.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          6.1665      0.601     10.260      0.000       4.988       7.345
# Stunting                      -0.0742      0.157     -0.473      0.636      -0.382       0.234
# age_m_r4                      -0.0033      0.013     -0.255      0.799      -0.029       0.022
# sexr1                          0.0614      0.097      0.636      0.525      -0.128       0.251
# Age_gap_r1                     0.0088      0.009      0.982      0.326      -0.009       0.026
# maternal_schooling_r1          0.0459      0.015      3.027      0.003       0.016       0.076
# no_of_household_members_r3    -0.0005      0.028     -0.020      0.984      -0.055       0.053
# household_assets_index_r3     -0.0200      0.048     -0.414      0.679      -0.115       0.075
# schooling_y_r5                -0.2511      0.015    -16.805      0.000      -0.280      -0.222
# ==============================================================================
# Omnibus:                      122.865   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              229.825
# Skew:                           0.490   Prob(JB):                     1.24e-50
# Kurtosis:                       4.479   Cond. No.                         579.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = df[['Stunting','age_m_r4','sexr1','Age_gap_r1','maternal_schooling_r1','no_of_household_members_r3','household_assets_index_r3','schooling_y_r5'
]] ## X usually means our input variables (or independent variables)
y = df["ISIC labour categories_r5.1"] ## Y usually means our output/dependent variable
X = sm.add_constant(X, prepend = False)## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.Logit(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.502540
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 Logit Regression Results
# =======================================================================================
# Dep. Variable:     ISIC labour categories_r5.1   No. Observations:                 1942
# Model:                                   Logit   Df Residuals:                     1933
# Method:                                    MLE   Df Model:                            8
# Date:                         Sun, 28 Feb 2021   Pseudo R-squ.:                 0.03386
# Time:                                 20:51:00   Log-Likelihood:                -975.93
# converged:                                True   LL-Null:                       -1010.1
# Covariance Type:                     nonrobust   LLR p-value:                 1.019e-11
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Stunting                      -0.0142      0.219     -0.065      0.948      -0.443       0.415
# age_m_r4                       0.0214      0.015      1.390      0.164      -0.009       0.051
# sexr1                         -0.5813      0.115     -5.038      0.000      -0.807      -0.355
# Age_gap_r1                    -0.0107      0.011     -0.944      0.345      -0.033       0.012
# maternal_schooling_r1          0.0161      0.016      0.980      0.327      -0.016       0.048
# no_of_household_members_r3    -0.0288      0.036     -0.802      0.422      -0.099       0.042
# household_assets_index_r3     -0.0213      0.061     -0.352      0.725      -0.140       0.097
# schooling_y_r5                 0.0676      0.019      3.655      0.000       0.031       0.104
# const                         -2.6486      0.716     -3.701      0.000      -4.051      -1.246
# ==============================================================================================
# """
